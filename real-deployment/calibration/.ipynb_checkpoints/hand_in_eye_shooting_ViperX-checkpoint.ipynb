# %% [markdown]
# # ViperX hand-in-eye data capture
#
# This notebook preserves the original Panda capture flow while replacing Panda hardware calls with the accepted ViperX model, Stage 4 mapping, and `ViperXAdapter`. It collects data only; hand-eye solving remains in `hand_in_eye_calib_ViperX.py`.
#
# ```text
# preflighted sparse q target -> adapter motion and settling -> 1.5 s buffer -> RGB/depth capture
#                             -> measured raw/q/FK snapshot -> one frame on disk
# ```
#
# Capture targets are generated directly in ViperX joint space around a small set of reviewed center poses. Each sample perturbs three distinct arm joints within fixed bounds, and FK supplies the target pose metadata. The complete plan is reproducible and preflighted before hardware connection. LeRobot normalized `.pos` is never used.

# %% [markdown]
# ## 1. Imports and laboratory paths

# %%
   import sys

   expected = "/data/yuzzhu/Re3Sim_ViperX/envs/re3sim-viperx-calib/bin/python"
   print("kernel_python=", sys.executable)
   assert sys.executable == expected, "Wrong Jupyter kernel selected."
   print("shooting_kernel_environment=PASS")
# Out:
# kernel_python= /data/yuzzhu/Re3Sim_ViperX/envs/re3sim-viperx-calib/bin/python
# shooting_kernel_environment=PASS

# %%
import cv2
import json
import shutil
import sys
import time
from pathlib import Path
from typing import Any

import numpy as np

PROJECT_ROOT = Path("/home/yuzzhu/Projects/Re3Sim_ViperX")
REAL_DEPLOYMENT_DIR = PROJECT_ROOT / "Re3Sim" / "real-deployment"
CALIBRATION_DIR = REAL_DEPLOYMENT_DIR / "calibration"
for module_dir in (REAL_DEPLOYMENT_DIR, CALIBRATION_DIR):
    if str(module_dir) not in sys.path:
        sys.path.insert(0, str(module_dir))

from lerobot.robots.utils import make_robot_from_config
from lerobot.robots.viperx.config_viperx import ViperXConfig
from realsense.realsense import Camera, get_devices
from viperx_adapter import (
    STARTUP_STAGING_Q_RAD,
    ViperXAdapter,
    ViperXUrdfMapping,
)
from viperx_model import load_viperx_model
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ## 2. Capture configuration
#
# Set the wrist-camera serial, reviewed startup anchor, and reviewed joint-space center poses. Each generated target stays within the configured per-joint delta of one center and passes q/eight-actuator raw preflight; this does not model collisions, cable clearance, or camera field of view, so every center must retain physical and image margin. Keep `STAGE5_LIVE_ACCEPTED` false until the Stage 5 acceptance gates are complete.

# %%
MAPPING_PATH = REAL_DEPLOYMENT_DIR / "configs" / "viperx_urdf_mapping.json"
DATA_ROOT = Path("/data/yuzzhu/Re3Sim_ViperX/data/viperx_hand_eye")
WRIST_CAMERA_SERIAL = "218622276584" # serial number for wrist camera.
RGB_RESOLUTION = (640, 480) # (width, height) in pixels
DEPTH_RESOLUTION = (640, 480)
CAMERA_WARMUP_S = 3.0
CAPTURE_SETTLE_S = 1.5
START_FRAME = 0 # data number to start from.
RETURN_HOME = True # home pose from mapping.
STAGE5_LIVE_ACCEPTED = True # safety check. Set True after validate adapter.

ANCHOR_Q_RAD = [
    -0.248505,
    -0.776194,
    0.872835,
    0.185612,
    0.299126,
    -0.371223,
] # None means start from home pose. could set by user in form of ANCHOR_Q_RAD = [q1, q2, q3, q4, q5, q6]
RANDOM_SEED = 20260723
SAMPLES_PER_CENTER = 10
JOINTS_PER_SAMPLE = 3
Q_DELTA_MAX_RAD = np.deg2rad([3.0, 3.0, 3.0, 5.0, 3.0, 4.0])

# %%
# Add four or five more center poses recorded with inspect_viperx_pose.py.
Q_CENTERS_RAD = [
    ANCHOR_Q_RAD,

    [-0.021476, -1.012427,  0.900447,  0.049087, 0.518486,  0.003068],
    [-0.070563, -1.099864,  0.420311, -0.015340, 0.951068, -0.061359],
    [-0.414175, -0.862097,  0.926524,  0.424913, 0.484738,  0.053689],
    [-0.084369, -0.427981,  0.280718,  0.027612, 0.877437, -0.105845],
    [-0.539961, -0.279185, -0.087437,  0.493942, 1.159689, -0.082835],
]

# %% [markdown]
# ## 3. Load the accepted ViperX stack and preflight targets
#
# This is the Panda replacement boundary. Mapping metadata supplies the LeRobot port, robot id, calibration directory, URDF, and fixed base/end frames. Every target is checked against both the kinematic limits and the eight-actuator raw mapping before any hardware connection.

# %%
def load_mapping_metadata(path: Path) -> dict[str, Any]:
    with path.expanduser().resolve().open("r", encoding="utf-8") as file:
        return json.load(file)


def generate_capture_plan(
    mapping: ViperXUrdfMapping,
    model: Any,
    q_centers_rad: np.ndarray,
    *,
    samples_per_center: int,
    joints_per_sample: int,
    q_delta_max_rad: np.ndarray,
    random_seed: int,
) -> tuple[np.ndarray, np.ndarray]:
    """Generate reproducible sparse joint-space targets and their ViperX FK."""

    q_centers = np.asarray(q_centers_rad, dtype=np.float64)
    joint_count = len(mapping.joint_order)
    if q_centers.ndim != 2 or q_centers.shape[0] == 0:
        raise ValueError("Q_CENTERS_RAD must be a nonempty two-dimensional array.")
    if q_centers.shape[1] != joint_count:
        raise ValueError(
            f"Q_CENTERS_RAD must have shape (N, {joint_count}), got {q_centers.shape}."
        )
    if samples_per_center <= 0:
        raise ValueError("SAMPLES_PER_CENTER must be positive.")
    if joints_per_sample <= 0 or joints_per_sample > joint_count:
        raise ValueError(f"JOINTS_PER_SAMPLE must be in [1, {joint_count}].")

    delta_max = np.asarray(q_delta_max_rad, dtype=np.float64)
    if delta_max.shape != (joint_count,):
        raise ValueError(f"Q_DELTA_MAX_RAD must have shape ({joint_count},).")
    if not np.all(np.isfinite(delta_max)) or np.any(delta_max < 0.0):
        raise ValueError("Q_DELTA_MAX_RAD must contain finite nonnegative values.")
    variable_joint_indices = np.flatnonzero(delta_max > 0.0)
    if len(variable_joint_indices) < joints_per_sample:
        raise ValueError(
            "Q_DELTA_MAX_RAD must enable at least JOINTS_PER_SAMPLE joints."
        )

    rng = np.random.default_rng(random_seed)
    q_targets = []
    target_poses = []

    for center_index, center in enumerate(q_centers):
        q_center = np.asarray(
            model.validate_joints(mapping.validate_q(center)), dtype=np.float64
        )
        mapping.rad_to_actuator_raw(q_center)

        for sample_index in range(samples_per_center):
            for _ in range(100):
                selected = rng.choice(
                    variable_joint_indices, size=joints_per_sample, replace=False
                )
                delta_q = np.zeros(joint_count, dtype=np.float64)
                delta_q[selected] = rng.uniform(-delta_max[selected], delta_max[selected])
                try:
                    q_target = np.asarray(
                        model.validate_joints(mapping.validate_q(q_center + delta_q)),
                        dtype=np.float64,
                    )
                    mapping.rad_to_actuator_raw(q_target)
                except ValueError:
                    continue
                break
            else:
                raise RuntimeError(
                    f"Could not sample a valid target for center {center_index}, "
                    f"sample {sample_index} after 100 attempts."
                )

            q_targets.append(q_target)
            target_poses.append(np.asarray(model.fk(q_target), dtype=np.float64))

    return np.stack(q_targets), np.stack(target_poses)


def create_adapter(
    mapping: ViperXUrdfMapping, metadata: dict[str, Any], model: Any
) -> ViperXAdapter:
    """Construct the LeRobot follower and inject it into the adapter."""

    lerobot = metadata["lerobot"]
    robot = make_robot_from_config(
        ViperXConfig(
            port=str(lerobot["port"]),
            id=str(lerobot["robot_id"]),
            calibration_dir=Path(str(lerobot["calibration_dir"])),
        )
    )
    return ViperXAdapter(robot, model, mapping, interactive_safety=True)


mapping = ViperXUrdfMapping.load(MAPPING_PATH)
mapping_metadata = load_mapping_metadata(MAPPING_PATH)
model = load_viperx_model(
    urdf_path=mapping_metadata["urdf_path"],
    base_link=mapping.base_link,
    end_link=mapping.end_link,
)
q_staging = np.asarray(
    model.validate_joints(mapping.validate_q(STARTUP_STAGING_Q_RAD)), dtype=np.float64
)
staging_raw_targets = mapping.rad_to_actuator_raw(q_staging)
anchor_q_rad = (
    mapping.q_home_urdf.copy()
    if ANCHOR_Q_RAD is None
    else np.asarray(ANCHOR_Q_RAD, dtype=np.float64)
)
anchor_q_rad = np.asarray(
    model.validate_joints(mapping.validate_q(anchor_q_rad)), dtype=np.float64
)
anchor_raw_targets = mapping.rad_to_actuator_raw(anchor_q_rad)
q_centers_rad = np.asarray(Q_CENTERS_RAD, dtype=np.float64)
q_targets_rad, target_poses = generate_capture_plan(
    mapping,
    model,
    q_centers_rad,
    samples_per_center=SAMPLES_PER_CENTER,
    joints_per_sample=JOINTS_PER_SAMPLE,
    q_delta_max_rad=Q_DELTA_MAX_RAD,
    random_seed=RANDOM_SEED,
)
print("joint_order=", mapping.joint_order)
print("startup_staging_raw_targets=", staging_raw_targets)
print("anchor_raw_targets=", anchor_raw_targets)
print("capture_center_count=", len(q_centers_rad))
print("capture_target_count=", len(q_targets_rad))
wrist_angles = q_targets_rad[:, 4]

print(
    "wrist_angle_range_rad=",
    float(np.min(wrist_angles)),
    float(np.max(wrist_angles)),
)
print(
    "min_abs_wrist_angle_rad=",
    float(np.min(np.abs(wrist_angles))),
)
print("random_seed=", RANDOM_SEED)
print("joint_space_fk_raw_preflight=PASS")
# Out:
# joint_order= ('waist', 'shoulder', 'elbow', 'forearm_roll', 'wrist_angle', 'wrist_rotate')
# startup_staging_raw_targets= {'waist': 2029, 'shoulder': 1339, 'elbow': 2978, 'forearm_roll': 2103, 'wrist_angle': 2563, 'wrist_rotate': 2194, 'shoulder_shadow': 1478, 'elbow_shadow': 2601}
# anchor_raw_targets= {'waist': 1900, 'shoulder': 1485, 'elbow': 2914, 'forearm_roll': 2149, 'wrist_angle': 2409, 'wrist_rotate': 1952, 'shoulder_shadow': 1624, 'elbow_shadow': 2537}
# capture_center_count= 6
# capture_target_count= 60
# wrist_angle_range_rad= 0.25600660007088316 1.1816343747244589
# min_abs_wrist_angle_rad= 0.25600660007088316
# random_seed= 20260723
# joint_space_fk_raw_preflight=PASS

# %% [markdown]
# ## 4. Dataset helpers
#
# The original Panda dataset folders remain compatible with `calibration.utils.read_data`. Additional `raw` and `metadata` records preserve the Stage 4 mapping boundary and the image/state timing information. `poses/pose_<frame>.npy` stores measured `T_base_hand`, not the commanded target.

# %%
def prepare_dataset(
    base_dir: Path,
    start_frame: int,
    frame_count: int,
) -> None:
    """Create the Panda-compatible dataset folders without overwriting frames."""

    for name in ("rgb", "depth", "poses", "joints", "raw", "metadata", "configs"):
        (base_dir / name).mkdir(parents=True, exist_ok=True)

    conflicts = []
    for frame_num in range(start_frame, start_frame + frame_count):
        candidates = (
            base_dir / "rgb" / f"{frame_num}.png",
            base_dir / "depth" / f"{frame_num}.npy",
            base_dir / "poses" / f"pose_{frame_num}.npy",
            base_dir / "joints" / f"joints_{frame_num}.npy",
            base_dir / "raw" / f"raw_{frame_num}.npy",
            base_dir / "metadata" / f"frame_{frame_num}.json",
        )
        conflicts.extend(path for path in candidates if path.exists())
    if conflicts:
        raise FileExistsError(f"Capture would overwrite existing frames: {conflicts}")


def save_camera_intrinsics(camera: Camera, base_dir: Path) -> None:
    """Save RGB/depth intrinsics in the original Panda file format."""

    rgb, _, depth, _ = camera.get_intrinsics_raw()
    np.savez(
        base_dir / "rgb_intrinsics.npz",
        fx=rgb.fx, fy=rgb.fy, ppx=rgb.ppx, ppy=rgb.ppy, coeffs=rgb.coeffs,
    )
    np.savez(
        base_dir / "depth_intrinsics.npz",
        fx=depth.fx,
        fy=depth.fy,
        ppx=depth.ppx,
        ppy=depth.ppy,
        coeffs=depth.coeffs,
        depth_scale=camera.get_depth_scale(),
    )


def save_capture_context(
    base_dir: Path,
    mapping: ViperXUrdfMapping,
    metadata: dict[str, Any],
    camera_serial: str,
    q_targets_rad: np.ndarray,
    target_poses: np.ndarray,
) -> None:
    """Copy small configuration inputs and write one capture manifest."""

    config_dir = base_dir / "configs"
    shutil.copy2(mapping.source_path, config_dir / mapping.source_path.name)
    calibration_file = Path(str(metadata["lerobot"]["calibration_file"]))
    if not calibration_file.is_file():
        raise FileNotFoundError(f"LeRobot calibration file not found: {calibration_file}")
    shutil.copy2(calibration_file, config_dir / calibration_file.name)

    manifest = {
        "created_at_s": time.time(),
        "camera_serial": camera_serial,
        "rgb_resolution": list(RGB_RESOLUTION),
        "depth_resolution": list(DEPTH_RESOLUTION),
        "capture_settle_s": CAPTURE_SETTLE_S,
        "joint_order": list(mapping.joint_order),
        "base_link": mapping.base_link,
        "end_link": mapping.end_link,
        "mapping_file": mapping.source_path.name,
        "calibration_file": calibration_file.name,
        "random_seed": RANDOM_SEED,
        "anchor_q_rad": anchor_q_rad.tolist(),
        "q_centers_rad": q_centers_rad.tolist(),
        "samples_per_center": SAMPLES_PER_CENTER,
        "joints_per_sample": JOINTS_PER_SAMPLE,
        "q_delta_max_rad": np.asarray(Q_DELTA_MAX_RAD).tolist(),
        "q_targets_rad": q_targets_rad.tolist(),
        "target_poses": target_poses.tolist(),
    }
    with (base_dir / "capture_manifest.json").open("w", encoding="utf-8") as file:
        json.dump(manifest, file, indent=2)
        file.write("\n")


def save_frame(
    base_dir: Path,
    frame_num: int,
    rgb_image: np.ndarray,
    depth_image: np.ndarray,
    camera_timestamp_s: float,
    q_target_rad: np.ndarray,
    target_pose: np.ndarray,
    observation: dict[str, Any],
    mapping: ViperXUrdfMapping,
) -> None:
    """Save one image pair and its measured ViperX state under one frame id."""

    q_measured = np.asarray(observation["joint_positions"], dtype=np.float64)
    ee_pose = np.asarray(observation["ee_pose"], dtype=np.float64)
    raw = observation["raw_joint_positions"]
    raw_array = np.asarray([raw[name] for name in mapping.joint_order], dtype=np.int64)

    rgb_path = base_dir / "rgb" / f"{frame_num}.png"
    bgr_image = cv2.cvtColor(np.asarray(rgb_image), cv2.COLOR_RGB2BGR)
    if not cv2.imwrite(str(rgb_path), bgr_image):
        raise IOError(f"Failed to save RGB image: {rgb_path}")
    np.save(base_dir / "depth" / f"{frame_num}.npy", depth_image)
    np.save(base_dir / "poses" / f"pose_{frame_num}.npy", ee_pose)
    np.save(base_dir / "joints" / f"joints_{frame_num}.npy", q_measured)
    np.save(base_dir / "raw" / f"raw_{frame_num}.npy", raw_array)

    frame_metadata = {
        "frame_id": frame_num,
        "camera_host_timestamp_s": camera_timestamp_s,
        "robot_timestamp_s": float(observation["timestamp_s"]),
        "joint_order": list(mapping.joint_order),
        "q_target_rad": np.asarray(q_target_rad, dtype=np.float64).tolist(),
        "target_pose": np.asarray(target_pose, dtype=np.float64).tolist(),
        "q_measured_rad": q_measured.tolist(),
        "raw_joint_positions": {name: int(raw[name]) for name in mapping.joint_order},
        "pose_semantics": "T_base_hand",
        "base_link": mapping.base_link,
        "end_link": mapping.end_link,
    }
    metadata_path = base_dir / "metadata" / f"frame_{frame_num}.json"
    with metadata_path.open("w", encoding="utf-8") as file:
        json.dump(frame_metadata, file, indent=2)
        file.write("\n")

# %% [markdown]
# ## 5. Panda-equivalent automatic capture
#
# For each target in the preflighted sparse joint-space plan, the adapter moves and verifies settling, then an explicit configurable buffer lets the arm and wrist camera stabilize before the RealSense frame is acquired. A measured robot observation follows immediately. On normal completion the arm returns to the accepted mapping home before entering hold/release.

# %%
def capture_images_viperx(
    adapter: ViperXAdapter,
    camera: Camera,
    q_targets_rad: np.ndarray,
    target_poses: np.ndarray,
    base_dir: Path,
    mapping: ViperXUrdfMapping,
    *,
    start_frame: int,
    camera_warmup_s: float,
    capture_settle_s: float,
    return_home: bool,
) -> None:
    """Move, capture, and save the Panda-equivalent ViperX dataset."""

    if not np.isfinite(capture_settle_s) or capture_settle_s < 0.0:
        raise ValueError("capture_settle_s must be finite and nonnegative.")

    camera_started = False
    try:
        camera.start()
        camera_started = True
        save_camera_intrinsics(camera, base_dir)
        camera.shoot()
        time.sleep(camera_warmup_s)

        for offset, (q_target_rad, target_pose) in enumerate(
            zip(q_targets_rad, target_poses, strict=True)
        ):
            frame_num = start_frame + offset
            print(f"Moving to capture target {offset + 1}/{len(q_targets_rad)}")
            adapter.move_joints(q_target_rad)
            time.sleep(capture_settle_s)

            rgb_image, depth_image = camera.shoot()
            camera_timestamp_s = time.time()
            if rgb_image is None or depth_image is None:
                raise RuntimeError(f"RealSense returned no frame for {frame_num}.")
            observation = adapter.get_obs()
            save_frame(
                base_dir,
                frame_num,
                rgb_image,
                depth_image,
                camera_timestamp_s,
                q_target_rad,
                target_pose,
                observation,
                mapping,
            )
            print(f"Saved capture frame {frame_num}")

        if return_home:
            adapter.go_home()
    finally:
        if camera_started:
            try:
                camera.stop()
            except Exception:
                pass

# %% [markdown]
# ## 6. Run on the laboratory host
#
# Run this cell only after Stage 5 is accepted, every center pose has been physically reviewed with enough collision/cable/FOV margin for the configured local q deltas, the wrist camera serial is explicit, the arm is supported as required, and the ChArUco board is fixed and visible. In Jupyter, use Interrupt/Ctrl-C for the first motion halt; after the adapter holds position, support the arm and answer the release prompt.

# %%
if not STAGE5_LIVE_ACCEPTED:
    raise RuntimeError("Stage 5 live acceptance is not recorded; capture is blocked.")
if not WRIST_CAMERA_SERIAL:
    raise ValueError("Set WRIST_CAMERA_SERIAL explicitly before capture.")

device_serials = get_devices()
if WRIST_CAMERA_SERIAL not in device_serials:
    raise RuntimeError(
        f"Wrist RealSense {WRIST_CAMERA_SERIAL!r} not found; detected {device_serials}."
    )

print("data_root=", DATA_ROOT)
print("camera_serial=", WRIST_CAMERA_SERIAL)
print("q_targets_rad=")
print(q_targets_rad)

confirmation = input("Type CAPTURE to connect hardware and execute this plan: ").strip()
if confirmation != "CAPTURE":
    raise RuntimeError("Capture aborted before hardware connection.")

prepare_dataset(DATA_ROOT, START_FRAME, len(q_targets_rad))
save_capture_context(
    DATA_ROOT,
    mapping,
    mapping_metadata,
    WRIST_CAMERA_SERIAL,
    q_targets_rad,
    target_poses,
)

adapter = create_adapter(mapping, mapping_metadata, model)
camera = Camera(WRIST_CAMERA_SERIAL, RGB_RESOLUTION, DEPTH_RESOLUTION)
try:
    adapter.connect()
    print("Moving from the unchecked startup state to the fixed staging pose")
    adapter.prepare_for_motion()
    print("Startup staging pose reached")
    print("Moving to the reviewed capture anchor")
    adapter.move_joints(anchor_q_rad)
    print("Capture anchor reached")
    capture_images_viperx(
        adapter,
        camera,
        q_targets_rad,
        target_poses,
        DATA_ROOT,
        mapping,
        start_frame=START_FRAME,
        camera_warmup_s=CAMERA_WARMUP_S,
        capture_settle_s=CAPTURE_SETTLE_S,
        return_home=RETURN_HOME,
    )
    adapter.stop_motion()
    adapter.await_release()
except BaseException:
    if adapter.is_connected:
        try:
            adapter.stop_motion()
        except Exception:
            pass
        if adapter.is_connected:
            try:
                adapter.await_release()
            except Exception:
                pass
    raise

print("hand_in_eye_capture=COMPLETE")
